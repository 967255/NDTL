# %%
from odes_hd import *

# %%
print(lv_tiny.info)
print(ode_shifted_list[2].info)
# Out:
# dx/dt = -36.0x + 36.0y
# dy/dt = -10.803 + 1.0x + 20.0y + 25.0z + -50.0xz
# dz/dt = 12.5 + -25.0x + -25.0y + -3.0z + 50.0xy
#
# dx/dt = -1800.0x + 1800.0y
# dy/dt = -540.15 + 50.0x + 1000.0y + 1250.0z + -2500.0xz
# dz/dt = 625.0 + -1250.0x + -1250.0y + -150.0z + 2500.0xy

# %%
lv_tiny.plot(init_point=[0.8,0.8,0.8], num_points=20000, h=0.01)
